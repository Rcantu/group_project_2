# %%
import requests
import pandas as pd
import xlrd
df = pd.read_excel (r'../project_22/DOW_KEY_RATIOS.xlsx')

# %%
import requests
import pandas as pd
import xlrd
df = pd.read_excel (r'../project_22/DOW_KEY_RATIOS.xlsx')

# %%
pd.concat(pd.read_excel("DOW_KEY_RATIOS.xlsx",sheet_name=None), ignore_index=True, sort=True)
# Out:
#                                     Quarter end  2019-06-29 00:00:00  \
# 0                                        Shares         4.519180e+09
# 1                         Shares split adjusted         4.519180e+09
# 2                                  Split factor         1.000000e+00
# 3                                        Assets         3.222390e+11
# 4                                Current Assets         1.349730e+11
# 5                                   Liabilities         2.257830e+11
# 6                           Current Liabilities         8.970400e+10
# 7                           Shareholders equity         9.645600e+10
# 8                      Non-controlling interest         0.000000e+00
# 9                              Preferred equity         0.000000e+00
# 10                       Goodwill & intangibles         0.000000e+00
# 11                               Long-term debt         8.493600e+10
# 12                                      Revenue         6.800000e+10
# ...

# %%
AAPL_df=pd.read_excel("DOW_KEY_RATIOS.xlsx", sheet_name="AAPL")


AAPL_df
# Out:
#                                    Quarter end  2019-06-29 00:00:00  \
# 0                                       Shares         4.519180e+09
# 1                        Shares split adjusted         4.519180e+09
# 2                                 Split factor         1.000000e+00
# 3                                       Assets         3.222390e+11
# 4                               Current Assets         1.349730e+11
# 5                                  Liabilities         2.257830e+11
# 6                          Current Liabilities         8.970400e+10
# 7                          Shareholders equity         9.645600e+10
# 8                     Non-controlling interest         0.000000e+00
# 9                             Preferred equity         0.000000e+00
# 10                      Goodwill & intangibles         0.000000e+00
# 11                              Long-term debt         8.493600e+10
# 12                                     Revenue         6.800000e+10
# ...

# %%
NVDA_df=pd.read_excel("DOW_KEY_RATIOS.xlsx", sheet_name="NVDA")
NVDA_df
# Out:
#                                    Quarter end  2019-04-28 00:00:00  \
# 0                                       Shares         6.090000e+08
# 1                        Shares split adjusted         6.090000e+08
# 2                                 Split factor         1.000000e+00
# 3                                       Assets         1.402100e+10
# 4                               Current Assets         1.062900e+10
# 5                                  Liabilities         4.317000e+09
# 6                          Current Liabilities         1.183000e+09
# 7                          Shareholders equity         9.704000e+09
# 8                     Non-controlling interest         0.000000e+00
# 9                             Preferred equity         0.000000e+00
# 10                      Goodwill & intangibles         6.720000e+08
# 11                              Long-term debt         1.988000e+09
# 12                                     Revenue         2.220000e+09
# ...

# %%
WMT_df=pd.read_excel("DOW_KEY_RATIOS.xlsx", sheet_name="WMT")

WMT_df
# Out:
#                                    Quarter end  2019-04-30 00:00:00  \
# 0                                       Shares         2.854722e+09
# 1                        Shares split adjusted         2.854722e+09
# 2                                 Split factor         1.000000e+00
# 3                                       Assets         2.345440e+11
# 4                               Current Assets         6.173900e+10
# 5                                  Liabilities         1.596340e+11
# 6                          Current Liabilities         7.988800e+10
# 7                          Shareholders equity         6.820500e+10
# 8                     Non-controlling interest         6.705000e+09
# 9                             Preferred equity         0.000000e+00
# 10                      Goodwill & intangibles         3.141600e+10
# 11                              Long-term debt         4.742500e+10
# 12                                     Revenue         1.239250e+11
# ...

# %%
MSFT_df=pd.read_excel("DOW_KEY_RATIOS.xlsx", sheet_name="MSFT")

MSFT_df
# Out:
#                                    Quarter end  2019-06-30 00:00:00  \
# 0                                       Shares         7.635409e+09
# 1                        Shares split adjusted         7.635409e+09
# 2                                 Split factor         1.000000e+00
# 3                                       Assets         2.865560e+11
# 4                               Current Assets         1.755520e+11
# 5                                  Liabilities         1.842260e+11
# 6                          Current Liabilities         6.942000e+10
# 7                          Shareholders equity         1.023300e+11
# 8                     Non-controlling interest         0.000000e+00
# 9                             Preferred equity         0.000000e+00
# 10                      Goodwill & intangibles         4.977600e+10
# 11                              Long-term debt         6.666200e+10
# 12                                     Revenue         3.371700e+10
# ...

# %%
GOOG_df=pd.read_excel("DOW_KEY_RATIOS.xlsx", sheet_name="GOOG")

GOOG_df
# Out:
#                                    Quarter end  2019-06-30 00:00:00  \
# 0                                       Shares         6.933984e+08
# 1                        Shares split adjusted         6.933984e+08
# 2                                 Split factor         1.000000e+00
# 3                                       Assets         2.571010e+11
# 4                               Current Assets         1.474370e+11
# 5                                  Liabilities         6.490900e+10
# 6                          Current Liabilities         3.700000e+10
# 7                          Shareholders equity         1.921920e+11
# 8                     Non-controlling interest         0.000000e+00
# 9                             Preferred equity         0.000000e+00
# 10                      Goodwill & intangibles         1.902000e+09
# 11                              Long-term debt         3.954000e+09
# 12                                     Revenue         3.265700e+10
# ...

# %%
AMZN_df=pd.read_excel("DOW_KEY_RATIOS.xlsx", sheet_name="AMZN")
AMZN_df=AMZN_df.dropna(axis='columns', how="all").dropna(axis="rows", how="any")

AMZN_df
# Out:
#                                    Quarter end  2019-06-30 00:00:00  \
# 0                                       Shares         4.946560e+08
# 1                        Shares split adjusted         4.946560e+08
# 2                                 Split factor         1.000000e+00
# 3                                       Assets         1.913510e+11
# 4                               Current Assets         7.679000e+10
# 5                                  Liabilities         1.382900e+11
# 6                          Current Liabilities         6.967800e+10
# 7                          Shareholders equity         5.306100e+10
# 8                     Non-controlling interest         0.000000e+00
# 9                             Preferred equity         0.000000e+00
# 10                      Goodwill & intangibles         1.472700e+10
# 11                              Long-term debt         2.332900e+10
# 12                                     Revenue         5.288600e+10
# ...

# %%
FB_df=pd.read_excel("DOW_KEY_RATIOS.xlsx", sheet_name="FB")

FB_df
# Out:
#                                    Quarter end  2019-06-30 00:00:00  \
# 0                                       Shares         2.852950e+09
# 1                        Shares split adjusted         2.852950e+09
# 2                                 Split factor         1.000000e+00
# 3                                       Assets         1.170060e+11
# 4                               Current Assets         5.796100e+10
# 5                                  Liabilities         2.824400e+10
# 6                          Current Liabilities         1.297900e+10
# 7                          Shareholders equity         8.876200e+10
# 8                     Non-controlling interest         0.000000e+00
# 9                             Preferred equity         0.000000e+00
# 10                      Goodwill & intangibles         9.940000e+08
# 11                              Long-term debt         0.000000e+00
# 12                                     Revenue         1.688600e+10
# ...

# %%
JPM_df=pd.read_excel("DOW_KEY_RATIOS.xlsx", sheet_name="JPM")
JPM_df=JPM_df.dropna(axis='columns', how="all").dropna(axis="rows", how="any")

JPM_df
# Out:
#                                    Quarter end  2019-03-31 00:00:00  \
# 0                                       Shares         3.243973e+09
# 1                        Shares split adjusted         3.243973e+09
# 2                                 Split factor         1.000000e+00
# 3                                       Assets         2.737188e+12
# 5                                  Liabilities         2.477351e+12
# 7                          Shareholders equity         2.598370e+11
# 8                     Non-controlling interest         0.000000e+00
# 9                             Preferred equity         2.699300e+10
# 10                      Goodwill & intangibles         0.000000e+00
# 11                              Long-term debt         0.000000e+00
# 12                                     Revenue         2.912300e+10
# 13                                    Earnings         9.179000e+09
# 14  Earnings available for common stockholders         9.179000e+09
# ...

# %%
V_df=pd.read_excel("DOW_KEY_RATIOS.xlsx", sheet_name="V")

V_df
# Out:
#                                    Quarter end  2019-06-30 00:00:00  \
# 0                                       Shares         1.983915e+09
# 1                        Shares split adjusted         1.983915e+09
# 2                                 Split factor         1.000000e+00
# 3                                       Assets         7.024900e+10
# 4                               Current Assets         1.830500e+10
# 5                                  Liabilities         3.525400e+10
# 6                          Current Liabilities         1.082900e+10
# 7                          Shareholders equity         3.499500e+10
# 8                     Non-controlling interest         0.000000e+00
# 9                             Preferred equity         5.462000e+09
# 10                      Goodwill & intangibles         4.258500e+10
# 11                              Long-term debt         1.669400e+10
# 12                                     Revenue         5.840000e+09
# ...

# %%
JNJ_df=pd.read_excel("DOW_KEY_RATIOS.xlsx", sheet_name="JNJ")

JNJ_df
# Out:
#                                    Quarter end  2019-06-30 00:00:00  \
# 0                                       Shares         2.639166e+09
# 1                        Shares split adjusted         2.639166e+09
# 2                                 Split factor         1.000000e+00
# 3                                       Assets         1.551170e+11
# 4                               Current Assets         4.179900e+10
# 5                                  Liabilities         9.433200e+10
# 6                          Current Liabilities         3.135300e+10
# 7                          Shareholders equity         6.078500e+10
# 8                     Non-controlling interest         0.000000e+00
# 9                             Preferred equity         0.000000e+00
# 10                      Goodwill & intangibles         8.299300e+10
# 11                              Long-term debt         2.769900e+10
# 12                                     Revenue         2.056200e+10
# ...

# %%
XOM_df=pd.read_excel("DOW_KEY_RATIOS.xlsx", sheet_name="XOM")
XOM_df
# Out:
#                                    Quarter end  2019-03-31 00:00:00  \
# 0                                       Shares         4.231094e+09
# 1                        Shares split adjusted         4.231094e+09
# 2                                 Split factor         1.000000e+00
# 3                                       Assets         3.561890e+11
# 4                               Current Assets         5.157600e+10
# 5                                  Liabilities         1.581680e+11
# 6                          Current Liabilities         6.663200e+10
# 7                          Shareholders equity         1.912220e+11
# 8                     Non-controlling interest         6.799000e+09
# 9                             Preferred equity         0.000000e+00
# 10                      Goodwill & intangibles         0.000000e+00
# 11                              Long-term debt         1.903100e+10
# 12                                     Revenue         6.164600e+10
# ...

# %%
BAC_df=pd.read_excel("DOW_KEY_RATIOS.xlsx", sheet_name="BAC")
BAC_df=BAC_df.dropna(axis='columns', how="all").dropna(axis="rows", how="any")

BAC_df
# Out:
#                                    Quarter end  2019-06-30 00:00:00  \
# 0                                       Shares         9.308301e+09
# 1                        Shares split adjusted         9.308301e+09
# 2                                 Split factor         1.000000e+00
# 3                                       Assets         2.395892e+12
# 5                                  Liabilities         2.124484e+12
# 7                          Shareholders equity         2.714080e+11
# 8                     Non-controlling interest         0.000000e+00
# 9                             Preferred equity         0.000000e+00
# 10                      Goodwill & intangibles         1.600000e+09
# 11                              Long-term debt         2.380110e+11
# 12                                     Revenue         2.308400e+10
# 13                                    Earnings         7.348000e+09
# 14  Earnings available for common stockholders         7.348000e+09
# ...

# %%
PG_df=pd.read_excel("DOW_KEY_RATIOS.xlsx", sheet_name="PG")

PG_df
# Out:
#                                    Quarter end  2019-03-31 00:00:00  \
# 0                                       Shares         2.508330e+09
# 1                        Shares split adjusted         2.508330e+09
# 2                                 Split factor         1.000000e+00
# 3                                       Assets         1.216730e+11
# 4                               Current Assets         2.231200e+10
# 5                                  Liabilities         6.612100e+10
# 6                          Current Liabilities         2.837000e+10
# 7                          Shareholders equity         5.507200e+10
# 8                     Non-controlling interest         4.800000e+08
# 9                             Preferred equity         9.330000e+08
# 10                      Goodwill & intangibles         7.258900e+10
# 11                              Long-term debt         2.135900e+10
# 12                                     Revenue         1.646200e+10
# ...

# %%
T_df=pd.read_excel("DOW_KEY_RATIOS.xlsx", sheet_name="PG")
#T_df.drop(columns= "symbol",inplace=True)

T_df
# Out:
#                                    Quarter end  2019-03-31 00:00:00  \
# 0                                       Shares         2.508330e+09
# 1                        Shares split adjusted         2.508330e+09
# 2                                 Split factor         1.000000e+00
# 3                                       Assets         1.216730e+11
# 4                               Current Assets         2.231200e+10
# 5                                  Liabilities         6.612100e+10
# 6                          Current Liabilities         2.837000e+10
# 7                          Shareholders equity         5.507200e+10
# 8                     Non-controlling interest         4.800000e+08
# 9                             Preferred equity         9.330000e+08
# 10                      Goodwill & intangibles         7.258900e+10
# 11                              Long-term debt         2.135900e+10
# 12                                     Revenue         1.646200e+10
# ...

# %%
HD_df=pd.read_excel("DOW_KEY_RATIOS.xlsx", sheet_name="HD")
HD_df
# Out:
#                                    Quarter end  2019-05-05 00:00:00  \
# 0                                       Shares         1.100286e+09
# 1                        Shares split adjusted         1.100286e+09
# 2                                 Split factor         1.000000e+00
# 3                                       Assets         5.151500e+10
# 4                               Current Assets         2.055300e+10
# 5                                  Liabilities         5.365800e+10
# 6                          Current Liabilities         1.967300e+10
# 7                          Shareholders equity        -2.143000e+09
# 8                     Non-controlling interest         0.000000e+00
# 9                             Preferred equity         0.000000e+00
# 10                      Goodwill & intangibles         2.250000e+09
# 11                              Long-term debt         2.680400e+10
# 12                                     Revenue         2.638100e+10
# ...

# %%
INTC_df=pd.read_excel("DOW_KEY_RATIOS.xlsx", sheet_name="INTC")
#INTC_df.drop(columns= "symbol",inplace=True)

INTC_df
# Out:
#                                    Quarter end  2019-06-29 00:00:00  \
# 0                                       Shares         4.430000e+09
# 1                        Shares split adjusted         4.430000e+09
# 2                                 Split factor         1.000000e+00
# 3                                       Assets         1.307590e+11
# 4                               Current Assets         2.923900e+10
# 5                                  Liabilities         5.556500e+10
# 6                          Current Liabilities         1.970500e+10
# 7                          Shareholders equity         7.494700e+10
# 8                     Non-controlling interest         2.470000e+08
# 9                             Preferred equity         0.000000e+00
# 10                      Goodwill & intangibles         3.583200e+10
# 11                              Long-term debt         2.508900e+10
# 12                                     Revenue         1.650500e+10
# ...

# %%
DIS_df=pd.read_excel("DOW_KEY_RATIOS.xlsx", sheet_name="DIS")
DIS_df=DIS_df.dropna(axis='columns', how="all").dropna(axis="rows", how="any")
DIS_df
# Out:
#                                    Quarter end  2018-12-29 00:00:00  \
# 0                                       Shares         1.490777e+09
# 1                        Shares split adjusted         1.490777e+09
# 2                                 Split factor         1.000000e+00
# 3                                       Assets         9.994100e+10
# 5                                  Liabilities         4.442400e+10
# 7                          Shareholders equity         5.031600e+10
# 8                     Non-controlling interest         5.201000e+09
# 9                             Preferred equity         0.000000e+00
# 10                      Goodwill & intangibles         3.803600e+10
# 11                              Long-term debt         2.066500e+10
# 12                                     Revenue         1.530300e+10
# 13                                    Earnings         2.788000e+09
# 14  Earnings available for common stockholders         2.788000e+09
# ...

# %%
VZ_df=pd.read_excel("DOW_KEY_RATIOS.xlsx", sheet_name="VZ")

VZ_df
# Out:
#                                    Quarter end  2019-03-31 00:00:00  \
# 0                                       Shares         4.135707e+09
# 1                        Shares split adjusted         4.135707e+09
# 2                                 Split factor         1.000000e+00
# 3                                       Assets         2.839470e+11
# 4                               Current Assets         3.339700e+10
# 5                                  Liabilities         2.264870e+11
# 6                          Current Liabilities         3.860700e+10
# 7                          Shareholders equity         5.585600e+10
# 8                     Non-controlling interest         1.604000e+09
# 9                             Preferred equity         0.000000e+00
# 10                      Goodwill & intangibles         1.284800e+11
# 11                              Long-term debt         1.050450e+11
# 12                                     Revenue         3.212800e+10
# ...

# %%
UNH_df=pd.read_excel("DOW_KEY_RATIOS.xlsx", sheet_name="UNH")

UNH_df
# Out:
#                                    Quarter end  2019-03-31 00:00:00  \
# 0                                       Shares         9.503431e+08
# 1                        Shares split adjusted         9.503431e+08
# 2                                 Split factor         1.000000e+00
# 3                                       Assets         1.611970e+11
# 4                               Current Assets         4.281500e+10
# 5                                  Liabilities         1.046920e+11
# 6                          Current Liabilities         5.893300e+10
# 7                          Shareholders equity         5.172400e+10
# 8                     Non-controlling interest         4.781000e+09
# 9                             Preferred equity         0.000000e+00
# 10                      Goodwill & intangibles         6.862400e+10
# 11                              Long-term debt         3.441900e+10
# 12                                     Revenue         6.030800e+10
# ...
